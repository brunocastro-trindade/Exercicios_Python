# %% [markdown]
# <a href="https://colab.research.google.com/github/brunocastro-trindade/Exercicios_Python/blob/main/Aula_de_Dados_Alura_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
#Comparador de numero maior, menor ou igual com estrutura de if, elif, else
num1 = int(input("Digite um numero para comparar: "))
num2 = int(input("Digite um segundo numero para comparar: "))

if num1 > num2:
  print(f"O numero {num1} é maior que o numero {num2}")
elif num1 < num2:
  print(f"O numero {num1} é menor que o numero {num2}")
elif num1 == num2:
  print(f"O numero {num1} é igual ao numero {num2}")
else:
  print("Digite um numero válido")

 #Calculando porcentual de aumento de lucro de uma empresa a partir de uma entrada de usuario
porcentual = float(input("Digite o porcentual de crescimento da sua empresa: "))

if porcentual > 0:
  print(f"Houve um crescimento de {porcentual:.2f}%")
elif porcentual < 0:
  print(f"Houve queda de {abs(porcentual):.2f%}")
else:
  print("A produção permaneceu estável.")

#Código que analisa entrada de consoante ou vogal:

letra = input("Digite uma letra: ")

if letra == "a" or (letra == "e") or (letra == "i") or (letra == "o") or (letra == "u"):
  print("A letra digitada é uma vogal")
else:
  print("A letra digitada é uma consoante")

#Atividade de pedir três entradas de valores e contabilizar a média entre eles:
prod1 = float(input("Digite o valor do primeiro produto: "))
prod2 = float(input("Digite o valor do segundo produto: "))
prod3 = float(input("Digite o valor do terceiro produto: "))

if prod1 < prod2 and prod1 < prod3:
  print(f"O produto de valor {prod1:.2f} é o mais barato")
elif prod2 < prod1 and prod2 < prod3:
  print(f"O produto de valor {prod2:.2f} é o mais barato")
else:
  print(f"O produto não está listado")


#Atividade de turno:

turno = input("Digite o turno que você estuda: ")

if turno == "manha" or turno == "Manhã":
  print("Bom dia!")
elif turno == "tarde" or turno == "Tarde":
  print("Boa tarde!")
elif turno == "noite" or turno == "Noite":
  print("Boa noite!")

#Estudos no Hyperskill

aniversario = input("É seu aniversário hoje?")
if aniversario == "sim":
  print("Parabéns")
else:
  print("Que pena")

#Definiu dois valores
def add_numbers(num1, num2):
  return num1 + num2
  #retornou eles com uma adição
result = add_numbers(5, 10)
print("The sum of the numbers is " + str(result))

x = [6, 5, 8, 2, 4, 0]
print(x[5] + x[2])



def parse_line(line):
    error_code = line[0:3]
    date = line[4:12]
    time = line[13:21]
    application_name = line[22:43]

    parsed_line = []
    parsed_line.insert(0, error_code)
    parsed_line.insert(1, date)
    parsed_line.insert(2, time)
    parsed_line.insert(3, application_name)

    return parsed_line

    if (error_code == "200"):
        return "Successful event - no parsing needed."

final_parsed_line = parse_line("200 02082022 05:11:00 buffer_application")
print(final_parsed_line)

for outer in range(2):
  for inner in range(3):
    print(f"{outer}, {inner}")

fruit = 'Banana'
fruit [0] = 'b'
print(fruit)

my_list = [1, 3, 5, 7, 9]
my_list.reverse()
print(my_list.reverse())

x = 0 #Valor inicial sendo 0
while x < 10: #Enquanto 0 for menor que 10
  print(x) #printa o valor
  x += 1 #o valor definido que no momento é 0 sendo percorrido +1 a cada laço do loop até 10

#Contador com while
contador = 1
while contador <= 3:
  nota_1 = int(input("Digite a nota do aluno: "))
  nota_2 = int(input("Digite a nota do aluno: "))

  print(f"Média: {(nota_1+nota_2)/2}")
  contador += 1

#Contador for
contador = 0
for contador in range(0,11,1):
  print(contador)

for contador in range(1,4):
   nota_1 = int(input("Digite a nota do aluno: "))
   nota_2 = int(input("Digite a nota do aluno: "))

   print(f"Média: {(nota_1+nota_2)/2}")

for i in range(1,6):
    if i == 4:
        continue
    print(i)

for i in range(1,6):
    if i == 4:
        break
    print(i)

#Atividade dois numeros inteiros rodando via loop for
num1 = int(input("Digite um numero inteiro: "))
num2 = int(input("Digite um numero inteiro: "))

for i in range(num1, num2, +1):
  print(i)

#TABUADA
num = int(input("Informe um número inteiro de 1 a 10: "))

print(f"Tabuada do número {num}:")

for i in range(1,11):
    resultado = num * i
    print(f"{num} X {i} = {resultado}")

num1 = float(input())
num2 = float(input())

resultado = num1 * num2

print(f"{resultado}")


# Solicitamos o número
num = int(input("Digite o número: "))

# Assumimos que o número é primo até que se prove o contrário
eh_primo = True

# Números abaixo de 2 não são primos
if num <= 1 :
  eh_primo = False
else:
    for i in range(2, num):
        # Se o número for divisível por qualquer número dentro deste intervalo,
        # ele não é primo, portanto, mudamos a variável 'eh_primo' para False e saímos do loop.
        if num % i == 0:
            eh_primo = False
            break

# Verifica se 'eh_primo' ainda é True, o que significa que o número passou pelo loop
# sem ser divisível por nenhum número além de 1 e ele mesmo.
if eh_primo:
    # Se for o caso, o número é primo.
    print(f'O número {num} é primo')
else:
    # Caso contrário, o número não é primo.
    print(f'O número {num} não é primo')

# Coletamos as idades dos clientes
idade = int(input('Informe a idade (ou um número negativo para encerrar): '))

# Inicializamos as variáveis de contadores
contador_0_25 = 0 # contador de idades entre 0 e 25
contador_26_50 = 0 # contador de idades entre 26 e 50
contador_51_75 = 0 # contador de idades entre 51 e 75
contador_76_100 = 0 # contador de idades entre 76 e 100

# nosso código executa sempre até o valor de idade for negativa
while idade >= 0:
    # contamos cada caso
    if idade >= 0 and idade <= 25:
        contador_0_25 += 1
    elif idade >= 26 and idade <= 50:
        contador_26_50 += 1
    elif idade >= 51 and idade <= 75:
        contador_51_75 += 1
    elif idade >= 76 and idade <= 100:
        contador_76_100 += 1

    # Repetir o processo de entrada de dados até que seja digitado um número negativo
    idade = int(input('Informe a idade (ou um número negativo para encerrar): '))

# Mostramos os resultados
print('Distribuição de idades:')
print('[0-25]:', contador_0_25)
print('[26-50]:', contador_26_50)
print('[51-75]:', contador_51_75)
print('[76-100]:', contador_76_100)


#dicionario em python
#Dicionarios tem sempre alguns elementos em comum o que muda é a forma que você trabalha com cada elemento:
pizza = {
    'name': 'Margherita Pizza',
    'price': 8.9,
    'calories_per_slice': 250,
    'toppings': ['mozzarella', 'basil']
}
print(pizza['price'])

frase = "Quem vigia os vigilantes?"
lista_palavras = frase.split()
print(lista_palavras)

misturas = ['Tintas: vermelho, azul e amarelo',

            'Verde: mistura de azul e amarelo',

            'Laranja: mistura de vermelho e amarelo',

            'Roxo: mistura de vermelho e azul']
unificador = '. '
string_misturas = unificador.join(misturas)
print(string_misturas)

lista = ['coreanas','japonesas','indianas','americanas','brasileiras','italianas']
print(lista[:2])
'''
#aprendendo sobre dicionarios
dicionario = {'matricula': 2000168933,
              'dia_de_cadastro': 25,
              'mês_de_cadastro': 10,
              'turma': '2E'}

for chaves, valores in dicionario.items():
  print(chaves, valores)
# Out:
# matricula 2000168933
# dia_de_cadastro 25
# mês_de_cadastro 10
# turma 2E
