# %% [markdown]
# <a href="https://colab.research.google.com/github/brunocastro-trindade/Exercicios_Python/blob/main/Aula_de_Dados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
#Aula 1
print('Escola de Dados da Alura!')
print('Nome: Bruno')
print('Sobrenome: Castro')
print('B')
print('R')
print('U')
print('N')
print('O')
print(18, 'maio', 1998)
print('Ano atual:', 2026)

Aula 2:

q_seguranca = 5
s_seguranca = 3000

q_docente = 16
s_docente = 6000

q_diretoria = 1
s_diretoria = 12500

q_total = q_seguranca + q_docente + q_diretoria
diferenca_salario = s_diretoria - s_seguranca

media_salario = (q_seguranca*s_seguranca + q_docente*s_docente + q_diretoria*s_diretoria) / (q_total)

print(q_total)
print(diferenca_salario)
print(media_salario)


nome = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))
print(f'Seu nome é {nome} e sua idade é, {idade}')

#Coleta e amostragem de dados:

nome = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))
altura = float(input('Digite sua altura: '))
print(f'Seu nome é {nome}, você tem {idade} anos e você tem {altura} metros de altura.')


minha_lista= ['a', 'b', 'c', 'd']
minha_lista[2] = 4
print(minha_lista)



lista = ['ab', 'cd', 'fg', 'ht', 'hj']
lista.insert(3, 'bg')
print(lista)


contador = 0

while contador < 10:
    print(f"Valor do contador é {contador}")
    contador += 1
else:
    print(f"Fim do while e o valor do contador é {contador}")


for num in range(10):
  if num == 5:
    break
  else:
    print(num)


num = 0
while num < 5:
    num += 1
    if num ==3:
        break
    print(num)

computador = ['Processador', 'Teclado', 'Mouse']
for indice, valor in enumerate(computador):
  print(f'Indice:{indice} | Valor={valor}')

frase = 'O Python é uma linguagem de programação '\
'multiparadigma. '\
'Python foi criado por Guido Van Rossum.'

i = 0
while i < len(frase):
    letra_atual = frase[1]
    quantas_vezes_letra_apareceu = frase.count(letra_atual)
    print(letra_atual)
    i += 1

# Isso é um formato de criação de lista em loop for
even_numbers = []

for num in range(21):
    if num % 2 == 0:
        even_numbers.append(num)
print(even_numbers)

#Criação de lista usando unica linha misturando conceito de loop com list comprehension

even_numbers = [num for num in range(21) if num % 2 == 0]
print(even_numbers)

start = int(input())
end = int(input())
step = int(input())

for i in range(start, end, step):
  print(i)


def number_pattern(n):
  if type(n) is not int:
      return "Argument must be an integer value."
  if n < 1:
      return "Argument must be an integer greater than 0."
  resultado = ""

  for numero in range(1, n + 1):
      resultado = resultado + str(numero) + " "

  return resultado.strip()


fruta = 'melancia'

print(list(fruta))
print(fruta[-4])
print(len(list(fruta)))

lista = ['mesa', 'cadeira', 'lavandeira', 'fogão']


numero_secreto = 7
guess = 0

while guess != numero_secreto:
    guess = int(input('Guess the number (1-10): '))
    if guess != numero_secreto:
        print('Wrong! Try again.')
print('Você acertou!')

desserts = ['Cake', 'Cookies', 'Ice Cream', 'Pie']
print(desserts[1:3])

if 2 < 8:
    print('2 é menor que 8')
else:
    print('2 não é menor que 8')

media = float(input('Digite a média: '))
if media >= 6.0:
    print("Aprovado")

elif media >= 5.0:
    print("Recuperação")

else:
    print("Reprovado")

for i in range(2): #Printa em um espaço até 2, começando pelo 0 indo ao 1 e não chegando ao 2
    for j in range(3): #Printa no limite de 3, sendo 1 2 3 dentro e aninhado a primeira requisição
        print(i, end=" ")#Printa i e end " " coloca espaços em cada "print"

# Obter entrada para linhas e colunas
rows = int(input())
cols = int(input())

# Escreva seus loops aninhados aqui
for i in range(rows):
    row = ""
    for j in range(cols):
        row += "*"
    print(row)

n = int(input())

for a in range(1, n + 1):
    for b in range(1, n + 1):
        if a * b == n:
            print(a, b)

quantidade = int(input())
soma = 0

for _ in range(quantidade):
    numero = int(input())
    soma += numero
print(soma)

lista_frutas = [1, 2, 3, 4]
lista_verduras = ["pepino", "tomate", "alface"]
new = lista_frutas.insert(4,5)
lista_verduras.append("batata")

print(lista_frutas+ lista_verduras)

def say_hello():
    print("Hello!")
say_hello()

def is_even(number):
    if number % 2 == 0:
        print(f"{number} is even")
    else:
        print(f"{number} is odd")

for i in range(15, 34):
    is_even(i)
for i in range(153, 219):
    is_even(i)


def calcular(num1, num2):
  print(num1 * num2)

num1 = int(input())
num2 = int(input())

calcular(num1, num2)

def calculate_area(length, width):
  print(length * width)

length = float(input())
width = float(input())

calculate_area(length, width)

def multiply(a, b):
  return a * b
multiply(3, 4)


def calculate():
    return 25
result = calculate()
print(result)

def cube_number(n):
    # Escreva seu código abaixo
    return cube_number
input_num = int(input())
result = cube_number(input_num)
print(result)

count = 0
for _ in range(5):
    count += 1
    if count == 4:
        break
    print(count)
units = 4
price = 8
total = units * price
print(total)

with open ("login_attempts.txt", "r") as file:
    file_text = file.read()
print(file_text)
'''
#Open, read, and split a text file
with open("login_attempts.txt", "r") as file:
    file_text = file.read()
usernames = file.text.split()

#Create a function that counts a user´s failed login attempts
def login_check(login_list, current_user):
    counter = 0
    for i in login_list:
        if i == current_user:
            counter = counter + ''
    if counter >= 3:
        return "You have tried to login three or more times"
    else:
        return "You can log in!"
login_check(usernames, "elarson")
